# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
from setup_nb_env import *

# pd.set_option('display.float_format', lambda x: '%.3f' % x)

DATA_DIR = '/work/users/k/4/k4thryn/Repos/EpSampling/data/'
DT = datetime.today().strftime('%Y%m%d-%H%M%S')

# pd.set_option('display.max_rows', 8)

# %%
from epsampling.data_processing import get_hub_df, get_death_df, get_acs_df, \
get_full_target_df, get_only_acs_covs_df

_df_acs = get_acs_df(37)
df_hub = get_hub_df(state_fips=37)
df_death = get_death_df(state_fips=37)
# Out:
# 100%|██████████| 210/210 [00:09<00:00, 21.61it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 6
#       4 _df_acs = get_acs_df(37)
#       5 df_hub = get_hub_df(state_fips=37)
# ----> 6 df_death = get_death_df(state_fips=37)
#
# File /work/users/k/4/k4thryn/Repos/OLD_EpSampling_Nov2024/notebooks/../epsampling/data_processing.py:93, in get_death_df(state_fips)
#      91 ## Pull out samples from 'nytimes' that have matched dates to 'COVIDhub-ensemble' ...
#      92 df['Date'] = df.Date.apply(lambda x: date_str_to_int(x))
# ---> 93 df_hub,_ = load_csv('formatted_COVIDhub-ensemble')
#      94 my_dates = df_hub.Date.unique().tolist()
#      95 df = df[df.Date.isin(my_dates)]
#
# File /work/users/k/4/k4thryn/Repos/OLD_EpSampling_Nov2024/notebooks/../epsampling/utils.py:49, in load_csv(csv_name, path, timestamp)
#      47     dates = [x[-19:-4] for x in files]
#      48     dates = sorted([x for x in dates if x[:3]=='202'])
# ---> 49     latest = dates[-1]
#      50 file_name = f'{path}{csv_name}_{latest}.csv'
#      51 df = pd.read_csv(file_name)
#
# IndexError: list index out of range

# %%
df = get_full_target_df(df_hub, df_death, _df_acs)
df_acs = get_only_acs_covs_df(_df_acs)

with pd.option_context('display.max_rows', 8):
    display('Census features:', df_acs)
    display('COV19 Hub state-level predictions:',df_hub)
    display('NYT reported county-level deaths',df_death)

# %%
display('Target-related attributes',df)
# Out:
# 'Target-related attributes'
#           Date  State_fips   Fips     Pop  State_pop     Ratio  \
# 0     20200620          37  37001  169185   10367022  0.016320
# 1     20200627          37  37001  169185   10367022  0.016320
# 2     20200704          37  37001  169185   10367022  0.016320
# 3     20200711          37  37001  169185   10367022  0.016320
# ...        ...         ...    ...     ...        ...       ...
# 9896  20220416          37  37199   18357   10367022  0.001771
# 9897  20220423          37  37199   18357   10367022  0.001771
# 9898  20220430          37  37199   18357   10367022  0.001771
# 9899  20220507          37  37199   18357   10367022  0.001771
#
#       Proj_state_inc_deaths  True_state_inc_deaths  True_county_cum_deaths  \
# 0                122.952377                  104.0                    35.0
# 1                100.308655                   95.0                    36.0
# 2                119.399124                   80.0                    37.0
# 3                100.119064                  106.0                    37.0
# ...                     ...                    ...                     ...
# 9896              41.000000                   76.0                    51.0
# 9897              60.000000                   29.0                    51.0
# 9898              33.000000                   42.0                    51.0
# 9899              33.000000                 1172.0                    57.0
#
#       True_county_inc_deaths  Naive_proj_deaths  Naive_true_deaths
# 0                        3.0           2.006526           1.697232
# 1                        1.0           1.636991           1.550356
# 2                        1.0           1.948538           1.305563
# 3                        0.0           1.633897           1.729871
# ...                      ...                ...                ...
# 9896                     0.0           0.072599           0.134574
# 9897                     0.0           0.106243           0.051351
# 9898                     0.0           0.058433           0.074370
# 9899                     6.0           0.058433           2.075273
#
# [9900 rows x 12 columns]

# %% [markdown]
# ### <font color=blue> Add time-varying variable: true_county_inc_deaths from t-4 to t-11 weeks.

# %%
from epsampling.data_processing import add_death_history_cols
df_tot = add_death_history_cols(df, target_col='True_county_inc_deaths')

with pd.option_context('display.min_rows', 20):
    display(df_tot)
# Out:
# 100%|██████████| 100/100 [00:11<00:00,  8.79it/s]
#           Date  State_fips   Fips     Pop  State_pop     Ratio  \
# 0     20200620          37  37001  169185   10367022  0.016320
# 1     20200627          37  37001  169185   10367022  0.016320
# 2     20200704          37  37001  169185   10367022  0.016320
# 3     20200711          37  37001  169185   10367022  0.016320
# 4     20200718          37  37001  169185   10367022  0.016320
# 5     20200725          37  37001  169185   10367022  0.016320
# 6     20200801          37  37001  169185   10367022  0.016320
# 7     20200808          37  37001  169185   10367022  0.016320
# 8     20200815          37  37001  169185   10367022  0.016320
# 9     20200822          37  37001  169185   10367022  0.016320
# ...        ...         ...    ...     ...        ...       ...
# 9890  20220305          37  37199   18357   10367022  0.001771
# 9891  20220312          37  37199   18357   10367022  0.001771
# 9892  20220319          37  37199   18357   10367022  0.001771
# 9893  20220326          37  37199   18357   10367022  0.001771
# 9894  20220402          37  37199   18357   10367022  0.001771
# 9895  20220409          37  37199   18357   10367022  0.001771
# 9896  20220416          37  37199   18357   10367022  0.001771
# 9897  20220423          37  37199   18357   10367022  0.001771
# 9898  20220430          37  37199   18357   10367022  0.001771
# 9899  20220507          37  37199   18357   10367022  0.001771
#
#       Proj_state_inc_deaths  True_state_inc_deaths  True_county_cum_deaths  \
# 0                122.952377                  104.0                    35.0
# 1                100.308655                   95.0                    36.0
# 2                119.399124                   80.0                    37.0
# 3                100.119064                  106.0                    37.0
# 4                120.176331                  133.0                    39.0
# 5                131.000000                  148.0                    40.0
# 6                152.000000                  188.0                    41.0
# 7                162.000000                  195.0                    41.0
# 8                208.000000                  186.0                    42.0
# 9                149.000000                  176.0                    44.0
# ...                     ...                    ...                     ...
# 9890             332.000000                  263.0                    51.0
# 9891             233.000000                  159.0                    51.0
# 9892             150.000000                  136.0                    51.0
# 9893             127.000000                  116.0                    51.0
# 9894             115.000000                   41.0                    51.0
# 9895              55.000000                   43.0                    51.0
# 9896              41.000000                   76.0                    51.0
# 9897              60.000000                   29.0                    51.0
# 9898              33.000000                   42.0                    51.0
# 9899              33.000000                 1172.0                    57.0
#
#       True_county_inc_deaths  Naive_proj_deaths  Naive_true_deaths  \
# 0                        3.0           2.006526           1.697232
# 1                        1.0           1.636991           1.550356
# 2                        1.0           1.948538           1.305563
# 3                        0.0           1.633897           1.729871
# 4                        2.0           1.961222           2.170498
# 5                        1.0           2.137859           2.415291
# 6                        1.0           2.480570           3.068073
# 7                        0.0           2.643765           3.182310
# 8                        1.0           3.394464           3.035434
# 9                        2.0           2.431611           2.872239
# ...                      ...                ...                ...
# 9890                     1.0           0.587876           0.465697
# 9891                     0.0           0.412576           0.281543
# 9892                     0.0           0.265607           0.240817
# 9893                     0.0           0.224880           0.205402
# 9894                     0.0           0.203632           0.072599
# 9895                     0.0           0.097389           0.076141
# 9896                     0.0           0.072599           0.134574
# 9897                     0.0           0.106243           0.051351
# 9898                     0.0           0.058433           0.074370
# 9899                     6.0           0.058433           2.075273
#
#      True_county_inc_deaths_tm_4 True_county_inc_deaths_tm_5  \
# 0                           None                        None
# 1                           None                        None
# 2                           None                        None
# 3                           None                        None
# 4                           None                        None
# 5                           None                        None
# 6                           None                        None
# 7                           None                        None
# 8                           None                        None
# 9                           None                        None
# ...                          ...                         ...
# 9890                         3.0                         1.0
# 9891                         1.0                         3.0
# 9892                         1.0                         1.0
# 9893                         0.0                         1.0
# 9894                         1.0                         0.0
# 9895                         0.0                         1.0
# 9896                         0.0                         0.0
# 9897                         0.0                         0.0
# 9898                         0.0                         0.0
# 9899                         0.0                         0.0
#
#      True_county_inc_deaths_tm_6 True_county_inc_deaths_tm_7  \
# 0                           None                        None
# 1                           None                        None
# 2                           None                        None
# 3                           None                        None
# 4                           None                        None
# 5                           None                        None
# 6                           None                        None
# 7                           None                        None
# 8                           None                        None
# 9                           None                        None
# ...                          ...                         ...
# 9890                         6.0                         1.0
# 9891                         1.0                         6.0
# 9892                         3.0                         1.0
# 9893                         1.0                         3.0
# 9894                         1.0                         1.0
# 9895                         0.0                         1.0
# 9896                         1.0                         0.0
# 9897                         0.0                         1.0
# 9898                         0.0                         0.0
# 9899                         0.0                         0.0
#
#      True_county_inc_deaths_tm_8 True_county_inc_deaths_tm_9  \
# 0                           None                        None
# 1                           None                        None
# 2                           None                        None
# 3                           None                        None
# 4                           None                        None
# 5                           None                        None
# 6                           None                        None
# 7                           None                        None
# 8                           None                        None
# 9                           None                        None
# ...                          ...                         ...
# 9890                         1.0                         0.0
# 9891                         1.0                         1.0
# 9892                         6.0                         1.0
# 9893                         1.0                         6.0
# 9894                         3.0                         1.0
# 9895                         1.0                         3.0
# 9896                         1.0                         1.0
# 9897                         0.0                         1.0
# 9898                         1.0                         0.0
# 9899                         0.0                         1.0
#
#      True_county_inc_deaths_tm_10 True_county_inc_deaths_tm_11
# 0                            None                         None
# 1                            None                         None
# 2                            None                         None
# 3                            None                         None
# 4                            None                         None
# 5                            None                         None
# 6                            None                         None
# 7                            None                         None
# 8                            None                         None
# 9                            None                         None
# ...                           ...                          ...
# 9890                          0.0                          0.0
# 9891                          0.0                          0.0
# 9892                          1.0                          0.0
# 9893                          1.0                          1.0
# 9894                          6.0                          1.0
# 9895                          1.0                          6.0
# 9896                          3.0                          1.0
# 9897                          1.0                          3.0
# 9898                          1.0                          1.0
# 9899                          0.0                          1.0
#
# [9900 rows x 20 columns]

# %%
## SAVE CSVs!
fpath = os.path.join(DATA_DIR,'processed',f'training_target_df_{DT}.csv')
df_tot.to_csv(fpath,index=False)
print(DT)

fpath = os.path.join(DATA_DIR,'processed',f'training_acs_df_{DT}.csv')
dff_acs.to_csv(fpath,index=False)
print(DT)
# Out:
# 20241108-123515
# 20241108-123515
