# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
from setup_nb_env import *

from epsampling.utils import load_csv
# pd.set_option('display.float_format', lambda x: '%.3f' % x)

DATA_DIR = '/work/users/k/4/k4thryn/Repos/EpSampling/data/'
DT = datetime.today().strftime('%Y%m%d-%H%M%S')

# %%
def drop_sers_with_nans(df, from_axis='rows'):
    
    if df.isnull().values.any()==True:
        print(f'Dropped {from_axis} with NaNs!')

        if from_axis=='rows':
            dff = df.dropna(axis=0, inplace=False)
            dff.reset_index(drop=True, inplace=True)
            print(f'Num rows before: {df.shape[0]}')
            print(f'Num rows after: {dff.shape[0]}')
            
        elif from_axis=='cols':
            dff = df.dropna(axis=1, inplace=False)
            print(f'Num cols before: {(df.shape[1])}')
            print(f'Num cols after: {(dff.shape[1])}')
            
        return dff
    
    else:
        print(f'No NaNs! :)')
        return df

# %%
timestamp = '20240928-145111'

fpath = os.path.join(DATA_DIR,'processed',f'formatted_state_fips_{timestamp}.csv')
df_fips = pd.read_csv(fpath)

# fpath = os.path.join(DATA_DIR,'processed',f'formatted_COVIDhub-ensemble_{timestamp}.csv')
# df_hub = pd.read_csv(fpath)

# fpath = os.path.join(DATA_DIR,'processed',f'formatted_nytimes-us-counties_{timestamp}.csv')
# df_nyt = pd.read_csv(fpath)

fpath = os.path.join(DATA_DIR,'processed',f'formatted_acs_results_{timestamp}.csv')
df_acs = pd.read_csv(fpath)

display(df_fips.head())
display(df_acs)
# Out:
#         State Postal  Fips
# 0     Alabama     AL     1
# 1      Alaska     AK     2
# 2     Arizona     AZ     4
# 3    Arkansas     AR     5
# 4  California     CA     6
#        Fips  POP_x2   POP_M   POP_F  POP_A0004  POP_A0509  POP_A1014  \
# 0      2013    3409    2014    1395        122        103        151
# 1      2016    5251    2995    2256        162        215        148
# 2      2020  292545  149648  142897      20218      20836      18642
# 3      2050   18514    9724    8790       1902       1923       1696
# 4      2060     849     480     369         67         41         28
# ...     ...     ...     ...     ...        ...        ...        ...
# 3137  56037   42459   21850   20609       2657       3456       3008
# 3138  56039   23319   12280   11039       1068       1032       1475
# 3139  56041   20514   10437   10077       1413       1712       1762
# 3140  56043    7768    4004    3764        399        321        606
# 3141  56045    6891    3684    3207        308        542        227
#
#       POP_A1517  POP_A1819  POP_A20  ...  HU_x15  HU_UIS01D  HU_UIS01A  \
# 0           106         52       37  ...    1113        835          3
# 1           110        154       55  ...    1456        417         70
# 2         11308       7022     3885  ...  118055      56649      16185
# 3          1028        612      261  ...    5992       4826        125
# 4            23          8        3  ...     922        711         33
# ...         ...        ...      ...  ...     ...        ...        ...
# 3137       1824       1193      485  ...   19174      11446        847
# 3138        575        569       64  ...   13255       7788       1314
# 3139        986        341      129  ...    8819       5230        606
# 3140        442        191       76  ...    3842       2847         87
# 3141        315        225       94  ...    3431       2376         63
#
#       HU_UIS02  HU_UIS0304  HU_UIS0509  HU_UIS1019  HU_UIS2049  HU_UIS50P  \
# 0           57          72          41          35           0          0
# 1          242         275         154          79         180         12
# 2         6372       12729        6852        4719        6892       2642
# 3          305         228          56          65         150          9
# 4           23          29          51          12           7          0
# ...        ...         ...         ...         ...         ...        ...
# 3137       478        1023         559         514         404         73
# 3138       555        1098        1056         505         404         97
# 3139        99         237         230         424         125         62
# 3140       128         267         128          22          17          5
# 3141        97          55          75          55          35          9
#
#       HU_UISOTHER
# 0              70
# 1              27
# 2            5015
# 3             228
# 4              56
# ...           ...
# 3137         3830
# 3138          438
# 3139         1806
# 3140          341
# 3141          666
#
# [3142 rows x 191 columns]

# %%
df = df_acs.copy()

def drop_duplicate_cols(df):
    uniq, idxs = np.unique(df, return_index=True, axis=1)
    return pd.DataFrame(uniq, index=df.index, columns=df.columns[idxs])

# Remove duplicate columns
df = drop_duplicate_cols(df)

## Rename cols
df.rename({'POP_x2':'Pop'},axis=1,inplace=True)
## Reorder columns
df = df[['Fips','Pop'] + [c for c in df.columns if c not in ['Fips','Pop']]]
df.head()
# Out:
#    Fips     Pop  OCC_MBSA_ELCAM_L  IND_AFFHM_MQE  IND_PSMAW_M  \
# 0  2013    3409                 0              0            0
# 1  2016    5251                 0              6            9
# 2  2020  292545              1842           2985          428
# 3  2050   18514                32             90          250
# 4  2060     849                 0              0            0
#
#    HU_OCC_OPRgt200  HU_UIS50P  IND_WHT_x7  HU_UIS2049  EDU_PROF  ...  HU_x14  \
# 0                0          0           0           0         1  ...    1113
# 1               11         12          47         180        14  ...    1456
# 2              499       2642        2860        6892      5415  ...  118055
# 3              239          9          19         150       102  ...    5992
# 4                0          0           2           7         1  ...     922
#
#     POP_F  POP_AIANNH  POP_AIAN  EDU_HS  POP_A3564   POP_M  POP_16p_EMP_x7  \
# 0    1395        1501      1505    1648       1760    2014            2213
# 1    2256         523       549    2626       2471    2995            3655
# 2  142897       19827     21150   94213     107273  149648          144598
# 3    8790       15427     15640    6485       5770    9724            6454
# 4     369         266       282     411        384     480             443
#
#    POP_A25p  POP_NH
# 0      2598    3050
# 1      3838    4740
# 2    193312  264762
# 3     10025   18131
# 4       643     740
#
# [5 rows x 161 columns]

# %% [markdown]
# ### <font color=blue> Get county ratios and insert state pop, state fips, and county ratio cols.

# %%
df.insert(2, 'State_fips', 0)
df.insert(3, 'State_pop',0)
df.insert(4, 'Ratio', 0)

df['Fips'] = df.Fips.astype(str)

for tup in df.itertuples():
    
    state_fips = tup.Fips[:-3]
    state_pop = sum(df[df.Fips.str[:-3]==state_fips].Pop)
    ratio = tup.Pop / state_pop
    
    df.at[tup.Index, 'State_fips'] = state_fips
    df.at[tup.Index, 'State_pop'] = state_pop
    df.at[tup.Index, 'Ratio'] = ratio

# %%
df
# Out:
#        Fips     Pop State_fips  State_pop     Ratio  OCC_MBSA_ELCAM_L  \
# 0      2013    3409          2     735951  0.004632                 0
# 1      2016    5251          2     735951  0.007135                 0
# 2      2020  292545          2     735951  0.397506              1842
# 3      2050   18514          2     735951  0.025157                32
# 4      2060     849          2     735951  0.001154                 0
# ...     ...     ...        ...        ...       ...               ...
# 3137  56037   42459         56     576641  0.073632               165
# 3138  56039   23319         56     576641  0.040439               209
# 3139  56041   20514         56     576641  0.035575                 0
# 3140  56043    7768         56     576641  0.013471                63
# 3141  56045    6891         56     576641  0.011950                12
#
#       IND_AFFHM_MQE  IND_PSMAW_M  HU_OCC_OPRgt200  HU_UIS50P  ...  HU_x14  \
# 0                 0            0                0          0  ...    1113
# 1                 6            9               11         12  ...    1456
# 2              2985          428              499       2642  ...  118055
# 3                90          250              239          9  ...    5992
# 4                 0            0                0          0  ...     922
# ...             ...          ...              ...        ...  ...     ...
# 3137           3135            0               30         73  ...   19174
# 3138             67            0               74         97  ...   13255
# 3139            748            0                8         62  ...    8819
# 3140            106            0                0          5  ...    3842
# 3141            572            0                0          9  ...    3431
#
#        POP_F  POP_AIANNH  POP_AIAN  EDU_HS  POP_A3564   POP_M  POP_16p_EMP_x7  \
# 0       1395        1501      1505    1648       1760    2014            2213
# 1       2256         523       549    2626       2471    2995            3655
# 2     142897       19827     21150   94213     107273  149648          144598
# 3       8790       15427     15640    6485       5770    9724            6454
# 4        369         266       282     411        384     480             443
# ...      ...         ...       ...     ...        ...     ...             ...
# 3137   20609         454       506   16349      16838   21850           20884
# 3138   11039          30        30    6148       9875   12280           14952
# 3139   10077          20        52    8432       7709   10437            9688
# 3140    3764          38        71    2992       2958    4004            3907
# 3141    3207          88        90    2980       2724    3684            3044
#
#       POP_A25p  POP_NH
# 0         2598    3050
# 1         3838    4740
# 2       193312  264762
# 3        10025   18131
# 4          643     740
# ...        ...     ...
# 3137     27816   35626
# 3138     17659   19835
# 3139     13233   18533
# 3140      5423    6651
# 3141      4892    6763
#
# [3142 rows x 164 columns]

# %%
## SAVE CSV!
DT = timestamp
fpath = os.path.join(DATA_DIR,'processed',f'formatted_acs_pop_ratio_{DT}.csv')
df.to_csv(fpath,index=False)
print(DT)

## READ BACK AND CHECK
dff = pd.read_csv(fpath)
display(df, dff)
dff.dtypes
# Out:
# 20240928-145111
#        Fips     Pop State_fips  State_pop     Ratio  OCC_MBSA_ELCAM_L  \
# 0      2013    3409          2     735951  0.004632                 0
# 1      2016    5251          2     735951  0.007135                 0
# 2      2020  292545          2     735951  0.397506              1842
# 3      2050   18514          2     735951  0.025157                32
# 4      2060     849          2     735951  0.001154                 0
# ...     ...     ...        ...        ...       ...               ...
# 3137  56037   42459         56     576641  0.073632               165
# 3138  56039   23319         56     576641  0.040439               209
# 3139  56041   20514         56     576641  0.035575                 0
# 3140  56043    7768         56     576641  0.013471                63
# 3141  56045    6891         56     576641  0.011950                12
#
#       IND_AFFHM_MQE  IND_PSMAW_M  HU_OCC_OPRgt200  HU_UIS50P  ...  HU_x14  \
# 0                 0            0                0          0  ...    1113
# 1                 6            9               11         12  ...    1456
# 2              2985          428              499       2642  ...  118055
# 3                90          250              239          9  ...    5992
# 4                 0            0                0          0  ...     922
# ...             ...          ...              ...        ...  ...     ...
# 3137           3135            0               30         73  ...   19174
# 3138             67            0               74         97  ...   13255
# 3139            748            0                8         62  ...    8819
# 3140            106            0                0          5  ...    3842
# 3141            572            0                0          9  ...    3431
#
#        POP_F  POP_AIANNH  POP_AIAN  EDU_HS  POP_A3564   POP_M  POP_16p_EMP_x7  \
# 0       1395        1501      1505    1648       1760    2014            2213
# 1       2256         523       549    2626       2471    2995            3655
# 2     142897       19827     21150   94213     107273  149648          144598
# 3       8790       15427     15640    6485       5770    9724            6454
# 4        369         266       282     411        384     480             443
# ...      ...         ...       ...     ...        ...     ...             ...
# 3137   20609         454       506   16349      16838   21850           20884
# 3138   11039          30        30    6148       9875   12280           14952
# 3139   10077          20        52    8432       7709   10437            9688
# 3140    3764          38        71    2992       2958    4004            3907
# 3141    3207          88        90    2980       2724    3684            3044
#
#       POP_A25p  POP_NH
# 0         2598    3050
# 1         3838    4740
# 2       193312  264762
# 3        10025   18131
# 4          643     740
# ...        ...     ...
# 3137     27816   35626
# 3138     17659   19835
# 3139     13233   18533
# 3140      5423    6651
# 3141      4892    6763
#
# [3142 rows x 164 columns]
#        Fips     Pop  State_fips  State_pop     Ratio  OCC_MBSA_ELCAM_L  \
# 0      2013    3409           2     735951  0.004632                 0
# 1      2016    5251           2     735951  0.007135                 0
# 2      2020  292545           2     735951  0.397506              1842
# 3      2050   18514           2     735951  0.025157                32
# 4      2060     849           2     735951  0.001154                 0
# ...     ...     ...         ...        ...       ...               ...
# 3137  56037   42459          56     576641  0.073632               165
# 3138  56039   23319          56     576641  0.040439               209
# 3139  56041   20514          56     576641  0.035575                 0
# 3140  56043    7768          56     576641  0.013471                63
# 3141  56045    6891          56     576641  0.011950                12
#
#       IND_AFFHM_MQE  IND_PSMAW_M  HU_OCC_OPRgt200  HU_UIS50P  ...  HU_x14  \
# 0                 0            0                0          0  ...    1113
# 1                 6            9               11         12  ...    1456
# 2              2985          428              499       2642  ...  118055
# 3                90          250              239          9  ...    5992
# 4                 0            0                0          0  ...     922
# ...             ...          ...              ...        ...  ...     ...
# 3137           3135            0               30         73  ...   19174
# 3138             67            0               74         97  ...   13255
# 3139            748            0                8         62  ...    8819
# 3140            106            0                0          5  ...    3842
# 3141            572            0                0          9  ...    3431
#
#        POP_F  POP_AIANNH  POP_AIAN  EDU_HS  POP_A3564   POP_M  POP_16p_EMP_x7  \
# 0       1395        1501      1505    1648       1760    2014            2213
# 1       2256         523       549    2626       2471    2995            3655
# 2     142897       19827     21150   94213     107273  149648          144598
# 3       8790       15427     15640    6485       5770    9724            6454
# 4        369         266       282     411        384     480             443
# ...      ...         ...       ...     ...        ...     ...             ...
# 3137   20609         454       506   16349      16838   21850           20884
# 3138   11039          30        30    6148       9875   12280           14952
# 3139   10077          20        52    8432       7709   10437            9688
# 3140    3764          38        71    2992       2958    4004            3907
# 3141    3207          88        90    2980       2724    3684            3044
#
#       POP_A25p  POP_NH
# 0         2598    3050
# 1         3838    4740
# 2       193312  264762
# 3        10025   18131
# 4          643     740
# ...        ...     ...
# 3137     27816   35626
# 3138     17659   19835
# 3139     13233   18533
# 3140      5423    6651
# 3141      4892    6763
#
# [3142 rows x 164 columns]
# Fips                      int64
# Pop                       int64
# State_fips                int64
# State_pop                 int64
# Ratio                   float64
# OCC_MBSA_ELCAM_L          int64
# IND_AFFHM_MQE             int64
# IND_PSMAW_M               int64
# HU_OCC_OPRgt200           int64
# HU_UIS50P                 int64
# IND_WHT_x7                int64
# HU_UIS2049                int64
# EDU_PROF                  int64
# HH_7pP                    int64
# OCC_MBSA_CES_CM           int64
# OCC_MBSA_HCPT_HTT         int64
# OCC_MBSA_ELCAM_ADESM      int64
# HU_UIS01A                 int64
# IND_FIRR_FI               int64
# OCC_SERV_HCS_x11          int64
# OCC_SERV_PS_LE            int64
# IND_INF_x7                int64
# EDU_DOCT                  int64
# POP_NHPINH                int64
# POP_NHPI                  int64
# OCC_MBSA_ELCAM_CSS        int64
# IND_PSMAW_PST             int64
# HHI_35_40k                int64
# HU_OCC_OPR151200          int64
# HHI_25_30k                int64
# HU_OCC_OPR101150          int64
# OCC_SERV_PS_FP            int64
# HH_6P                     int64
# POP_A21                   int64
# IND_CONS_x7               int64
# IND_OSER_x7               int64
# OCC_MBSA_CES_LPSS         int64
# IND_AERAF_AER             int64
# OCC_MBSA_CES_AE           int64
# HHI_45_50k                int64
# HHI_40_45k                int64
# OCC_MBSA_MBF_BF           int64
# OCC_MBSA_HCPT_HDTP        int64
# IND_TWU_U                 int64
# OCC_SERV_PS               int64
# OCC_MBSA_HCPT             int64
# POP_A7579                 int64
# HHI_00_10k                int64
# IND_FIRR_RR               int64
# IND_PSMAW_ASWM            int64
# HU_UIS1019                int64
# HHI_10_15k                int64
# HHI_15_20k                int64
# POP_A20                   int64
# HHI_30_35k                int64
# IND_FIRR                  int64
# HU_UIS0509                int64
# OCC_SERV_FPS_x11          int64
# OCC_PTMM_T_x11            int64
# OCC_SERV_PCS_x11          int64
# POP_A85p                  int64
# POP_A8084                 int64
# IND_PSMAW                 int64
# HHI_200k_p                int64
# POP_A1819                 int64
# OCC_MBSA_CES              int64
# IND_AERAF_AF              int64
# OCC_NRCM_IMR_x11          int64
# HU_UIS02                  int64
# POP_BLACKNH               int64
# HHI_20_25k                int64
# HH_5P                     int64
# IND_RETT_x7               int64
# HU_UISOTHER               int64
# OCC_NRCM_CE_x11           int64
# POP_BLACK                 int64
# HU_UIS0304                int64
# IND_TWU_TW                int64
# HHI_60_75k                int64
# OCC_SALES_SR_x11          int64
# HHI_150_200k              int64
# IND_AERAF                 int64
# HH_4P                     int64
# HHI_50_60k                int64
# POP_A6769                 int64
# POP_A7074                 int64
# IND_EHCSA_HCSA            int64
# POP_A6264                 int64
# HHI_125_150k              int64
# POP_A6566                 int64
# HHI_100_125k              int64
# OCC_PTMM_MM_x11           int64
# IND_TWU                   int64
# POP_A0509                 int64
# POP_A1517                 int64
# POP_A0004                 int64
# HHI_75_100k               int64
# OCC_MBSA_ELCAM_EL         int64
# IND_EHCSA_E               int64
# EDU_MAST                  int64
# HH_3P                     int64
# EDU_ASSOC                 int64
# OCC_MBSA_ELCAM            int64
# POP_A1014                 int64
# POP_A6061                 int64
# OCC_NRCM_FFF_x11          int64
# OCC_SERV_BGM_x11          int64
# OCC_SALES_OAS_x11         int64
# POP_A4044                 int64
# POP_A2529                 int64
# HU_VAC                    int64
# IND_EHCSA                 int64
# IND_AFFHM_AFFH            int64
# IND_AFFHM                 int64
# POP_A2224                 int64
# HU_OCC_OPR051100          int64
# POP_A3034                 int64
# OCC_SALES                 int64
# HH_1P                     int64
# OCC_MBSA_MBF_M            int64
# EDU_BACH                  int64
# OCC_NRCM                  int64
# OCC_SERV                  int64
# POP_A5559                 int64
# OCC_MBSA_MBF              int64
# HINS_A1934                int64
# POP_OTH2PLNH              int64
# POP_A5054                 int64
# POP_A3539                 int64
# HINS_A0018                int64
# IND_PUBA_x7               int64
# HH_2P                     int64
# HU_OCC_RENT               int64
# POP_A4549                 int64
# POP_HISP_x12              int64
# HINS_A65p                 int64
# EDU_ltHS                  int64
# POP_A65p                  int64
# POP_WHITENH               int64
# POP_WHITE                 int64
# POP_A0018                 int64
# OCC_MBSA                  int64
# HU_OCC_OWN                int64
# POP_OTH2PL                int64
# HU_OCC_OPRlt050           int64
# OCC_PTMM_P_x11            int64
# POP_ASIANNH               int64
# POP_ASIAN                 int64
# POP_A1934                 int64
# HU_UIS01D                 int64
# OCC_PTMM                  int64
# HH_x5                     int64
# HINS_A3564                int64
# IND_MAN_x7                int64
# HU_x14                    int64
# POP_F                     int64
# POP_AIANNH                int64
# POP_AIAN                  int64
# EDU_HS                    int64
# POP_A3564                 int64
# POP_M                     int64
# POP_16p_EMP_x7            int64
# POP_A25p                  int64
# POP_NH                    int64
# dtype: object
