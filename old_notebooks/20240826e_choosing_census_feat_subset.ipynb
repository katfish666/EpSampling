# %%
import census
import us
from us import states
import pandas as pd
import json
import yaml

c = census.Census("411bb7f85fae9359b2096fd35aa2760d7c95fdae", year=2020)

# %% [markdown]
# ### <font color=blue> Load all feature codes.

# %%
## Save census info dictionaries for later

# import json

# tables = c.acs5.tables()
# fields = c.acs5.fields()

# fields.pop('ucgid')

# with open('cached_data/acs5_2020_fields.json','w') as f:
#     json.dump(fields, f)
    
# with open('cached_data/acs5_2020_tables.json','w') as f:
#     json.dump(tables, f)

# # # # # # # # # # # # # # # # # # # # # # # #
# # # # # # # # # # # # # # # # # # # # # # # #

import json

with open('cached_data/acs5_2020_fields.json') as f:
    fields = json.load(f)
    
with open('cached_data/acs5_2020_tables.json') as f:
    tables = json.load(f)

# %%
list(fields.values())[0]
# Out:
# {'label': 'Estimate!!Total:!!Female:!!Service occupations:!!Food preparation and serving related occupations',
#  'concept': 'SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#  'predicateType': 'int',
#  'group': 'B24022',
#  'limit': 0,
#  'attributes': 'B24022_060EA,B24022_060M,B24022_060MA'}

# %%
l = list(fields.values())[:20]

for x in l:
    print(x['label'],'\n', x['concept'],'\n\n')
# Out:
# Estimate!!Total:!!Female:!!Service occupations:!!Food preparation and serving related occupations
#  SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER
#
#
# Estimate!!Total:!!$100,000 to $124,999
#  HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)
#
#
# Estimate!!Total:!!Moved from different municipio:!!Foreign born:!!Naturalized U.S. citizen
#  GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY CITIZENSHIP STATUS FOR CURRENT RESIDENCE IN PUERTO RICO
#
#
# Estimate!!Total:!!$15,000 to $19,999
#  FAMILY INCOME IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)
#
#
# Estimate!!Total:!!Female:!!Service occupations:!!Building and grounds cleaning and maintenance occupations
# ...

# %%
tables[0]
# Out:
# {'name': 'B17015',
#  'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY SOCIAL SECURITY INCOME BY SUPPLEMENTAL SECURITY INCOME (SSI) AND CASH PUBLIC ASSISTANCE INCOME',
#  'variables': 'http://api.census.gov/data/2020/acs/acs5/groups/B17015.json',
#  'universe ': 'FAMILY'}

# %%
df_tables = pd.DataFrame(tables)
df_tables.columns = df_tables.columns.str.rstrip()
df_tables = df_tables.drop('variables',axis=1)

len(df_tables.universe.unique())
# Out:
# 405

# %%
df_tables
# Out:
#         name                                        description  \
# 0     B17015  POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# 1     B18104                 SEX BY AGE BY COGNITIVE DIFFICULTY
# 2     B17016  POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILI...
# 3     B18105                SEX BY AGE BY AMBULATORY DIFFICULTY
# 4     B17017  POVERTY STATUS IN THE PAST 12 MONTHS BY HOUSEH...
# ...      ...                                                ...
# 1135  B99131  ALLOCATION OF MARITAL STATUS FOR FEMALES 15 TO...
# 1136  B09018  RELATIONSHIP TO HOUSEHOLDER FOR CHILDREN UNDER...
# 1137  B09019  HOUSEHOLD TYPE (INCLUDING LIVING ALONE) BY REL...
# 1138  B99132    ALLOCATION OF FERTILITY OF WOMEN 15 TO 50 YEARS
# 1139  B09010  RECEIPT OF SUPPLEMENTAL SECURITY INCOME (SSI),...
#
#                      universe
# 0                      FAMILY
# 1             NONINST_05_OVER
# 2                      FAMILY
# 3             NONINST_05_OVER
# 4                       HSHLD
# ...

# %%
df_fields = pd.DataFrame(fields)
# df_fields = df_fields.T
# df_fields.columns = df_fields.columns.str.rstrip()
# df_fields = df_tables.drop('variables',axis=1)

df_fields
# Out:
#                                                      B24022_060E  \
# label          Estimate!!Total:!!Female:!!Service occupations...
# concept        SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE P...
# predicateType                                                int
# group                                                     B24022
# limit                                                          0
# attributes                 B24022_060EA,B24022_060M,B24022_060MA
# required                                                     NaN
#
#                                                     B19001B_014E  \
# label                     Estimate!!Total:!!$100,000 to $124,999
# concept        HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 202...
# predicateType                                                int
# group                                                    B19001B
# limit                                                          0
# ...

# %%
len({k:v for k,v in fields.items() if '001E' in k})
# Out:
# 1275

# %%
# fields

# %%
word = 'EDUCATIONAL ATTAINMENT'
word = 'DOCTORATE'
# word = ''

l = []
for k,v in fields.items():
    try:
        
        if "B15003" in k:
#             print(k, v, '\n')
#         if word in v['concept'] or word.lower() in v['label'].lower():
            l.append([k,v])
    #         print(k,v)
    except:
        continue

print(len(l))
[print(x, '\n') for x in l]
# Out:
# 25
# ['B15003_025E', {'label': 'Estimate!!Total:!!Doctorate degree', 'concept': 'EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER', 'predicateType': 'int', 'group': 'B15003', 'limit': 0, 'attributes': 'B15003_025EA,B15003_025M,B15003_025MA'}]
#
# ['B15003_024E', {'label': 'Estimate!!Total:!!Professional school degree', 'concept': 'EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER', 'predicateType': 'int', 'group': 'B15003', 'limit': 0, 'attributes': 'B15003_024EA,B15003_024M,B15003_024MA'}]
#
# ['B15003_023E', {'label': "Estimate!!Total:!!Master's degree", 'concept': 'EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER', 'predicateType': 'int', 'group': 'B15003', 'limit': 0, 'attributes': 'B15003_023EA,B15003_023M,B15003_023MA'}]
#
# ...

# %%
word = 'Estimate!!Total:!!Service occupations:!!Protective service occupations:'

l = []
for k,v in fields.items():
    try:
        
#         if "B15003" in k:
#             print(k, v, '\n')
        if word.lower() in v['concept'].lower() or word.lower() in v['label'].lower():
            #if "dollars" in v.lower() or "dollars" in k.lower():
            #    continue
            #if v['label'] != "Estimate!!Total:":
            #    continue
            l.append([k,v])
    #         print(k,v)
    except:
        continue

print(len(l))
[print(x, '\n') for x in l]
# Out:
# 6
# ['B24011_022E', {'label': 'Estimate!!Total:!!Service occupations:!!Protective service occupations:!!Law enforcement workers including supervisors', 'concept': 'OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER', 'predicateType': 'int', 'group': 'B24011', 'limit': 0, 'attributes': 'B24011_022EA,B24011_022M,B24011_022MA'}]
#
# ['B24011_021E', {'label': 'Estimate!!Total:!!Service occupations:!!Protective service occupations:!!Firefighting and prevention, and other protective service workers including supervisors', 'concept': 'OCCUPATION BY MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2020 INFLATION-ADJUSTED DOLLARS) FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER', 'predicateType': 'int', 'group': 'B24011', 'limit': 0, 'attributes': 'B24011_021EA,B24011_021M,B24011_021MA'}]
#
# ...

# %%
# fields_001E = {k:v for k,v in fields.items() if '001E' in k}

# for k,v in fields_001E.items():
#     print(v['concept'],'\n')
# #     break

# print (fields_001E)

# fields_001E['B24081_001E']
