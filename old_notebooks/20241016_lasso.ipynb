# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
from setup_nb_env import *

from epsampling.utils import load_csv
# pd.set_option('display.float_format', lambda x: '%.3f' % x)
from epsampling.utils import drop_sers_with_nans
from epsampling.utils import date_str_to_int

DATA_DIR = '/work/users/k/4/k4thryn/Repos/EpSampling/data/'
DT = datetime.today().strftime('%Y%m%d-%H%M%S')

# %%
timestamp = '20241009-144131'

fpath = os.path.join(DATA_DIR,'processed', f'processed_naive_deaths_{timestamp}.csv')
df_deaths = pd.read_csv(fpath)
# display(df)

## Drop rows with nans.
df_deaths.dropna(inplace=True)
# display(df)

## Drop samples with negative inc deaths.
df_deaths = df_deaths[df_deaths.True_inc_deaths >= 0]
# display(df_deaths)

# # # # # # # # # # # # # # # # # # # #
# # # # # # # # # # # # # # # # # # # # 

from epsampling.utils import drop_duplicate_cols

# timestamp = '20241009-143022' 

fpath = os.path.join(DATA_DIR,'processed',f'formatted_acs_results_normed_{timestamp}.csv')
df_acs = pd.read_csv(fpath,index_col='Fips')

# Remove duplicate columns
df_acs = drop_duplicate_cols(df_acs)

# %%
df = df_deaths.merge(df_acs, on='Fips')
display(df)
# Out:
#          Fips  State_fips      Pop  State_pop     Ratio      Date  \
# 0        1001           1  58239.0    4997675  0.011653  20200620
# 1        1001           1  58239.0    4997675  0.011653  20200627
# 2        1001           1  58239.0    4997675  0.011653  20200704
# 3        1001           1  58239.0    4997675  0.011653  20200711
# 4        1001           1  58239.0    4997675  0.011653  20200718
# ...       ...         ...      ...        ...       ...       ...
# 304412  56045          56   6891.0     576641  0.011950  20220409
# 304413  56045          56   6891.0     576641  0.011950  20220416
# 304414  56045          56   6891.0     576641  0.011950  20220423
# 304415  56045          56   6891.0     576641  0.011950  20220430
# 304416  56045          56   6891.0     576641  0.011950  20220507
#
#         Proj_inc_deaths  True_cum_deaths  Cum_deaths_tm1  True_inc_deaths  \
# 0             83.302156              9.0             6.0              3.0
# 1             68.179357             12.0             9.0              3.0
# 2             76.238975             13.0            12.0              1.0
# 3             88.362530             15.0            13.0              2.0
# 4            114.279381             21.0            15.0              6.0
# ...                 ...              ...             ...              ...
# 304412         8.000000             18.0            18.0              0.0
# 304413         5.000000             18.0            18.0              0.0
# 304414         4.000000             18.0            18.0              0.0
# 304415         4.000000             18.0            18.0              0.0
# 304416         4.000000             18.0            18.0              0.0
#
#         ...    HU_OCC    POP_NH  HINS_A0018  HINS_A65p    HH_x5  POP_A3564  \
# 0       ...  0.904261  0.969522    0.979290   0.998043  21856.0    22690.0
# 1       ...  0.904261  0.969522    0.979290   0.998043  21856.0    22690.0
# 2       ...  0.904261  0.969522    0.979290   0.998043  21856.0    22690.0
# 3       ...  0.904261  0.969522    0.979290   0.998043  21856.0    22690.0
# 4       ...  0.904261  0.969522    0.979290   0.998043  21856.0    22690.0
# ...     ...       ...       ...         ...        ...      ...        ...
# 304412  ...  0.802681  0.981425    0.844977   1.000000   2754.0     2724.0
# 304413  ...  0.802681  0.981425    0.844977   1.000000   2754.0     2724.0
# 304414  ...  0.802681  0.981425    0.844977   1.000000   2754.0     2724.0
# 304415  ...  0.802681  0.981425    0.844977   1.000000   2754.0     2724.0
# 304416  ...  0.802681  0.981425    0.844977   1.000000   2754.0     2724.0
#
#          HU_x14  POP_16p_EMP_x7  POP_A25p   POP_x2
# 0       24170.0         25871.0   39614.0  58239.0
# 1       24170.0         25871.0   39614.0  58239.0
# 2       24170.0         25871.0   39614.0  58239.0
# 3       24170.0         25871.0   39614.0  58239.0
# 4       24170.0         25871.0   39614.0  58239.0
# ...         ...             ...       ...      ...
# 304412   3431.0          3044.0    4892.0   6891.0
# 304413   3431.0          3044.0    4892.0   6891.0
# 304414   3431.0          3044.0    4892.0   6891.0
# 304415   3431.0          3044.0    4892.0   6891.0
# 304416   3431.0          3044.0    4892.0   6891.0
#
# [304417 rows x 169 columns]

# %%
df['Target'] = df.apply(lambda x: x.True_inc_deaths / x.Pop * 100000, axis=1)
df['Naive'] = df.apply(lambda x: x.Naive_inc_deaths / x.Pop * 100000, axis=1)
df['State'] = df.apply(lambda x: x.Proj_inc_deaths / x.State_pop * 100000, axis=1)
df['Cumtm1'] = df.apply(lambda x: x.Cum_deaths_tm1 / x.Pop * 100000, axis=1)

# df['Target'] = df.apply(lambda x: x.True_inc_deaths, axis=1)
# df['Naive'] = df.apply(lambda x: x.Naive_inc_deaths, axis=1)
# df['State'] = df.apply(lambda x: x.Proj_inc_deaths, axis=1)
# df['Cumtm1'] = df.apply(lambda x: x.Cum_deaths_tm1, axis=1)

# %%
# # min-max normalization
# df = (df - df.min()) / (df.max() - df.min())

# %%
def get_chunks(lst, n):
    """Return successive n-sized chunks from lst."""
    chunks = []
    for i in range(0, len(lst), n):
        chunks.append(lst[i:i + n])
    return chunks

# %%
chunks = get_chunks(list(df.Date.unique()), 4)

# idc = [2,10,18]
# idc = [10]

# for idx in idc:
    
idx = 18 #10

dates_test = chunks[idx]
dates_train = [x for x in df.Date.unique() if x not in dates_test]

df_train = df[df.Date.isin(dates_train)]
df_test = df[df.Date.isin(dates_test)]

feats = list(df_acs.columns) + ['State','Cumtm1','Naive',
                               'State_pop','Ratio','Pop']
print(feats)

X_train = df_train[feats]
X_test = df_test[feats]

y_train = df_train['Target']
y_test = df_test['Target']

y_naive = df_test['Naive']
# Out:
# ['POP_NHPINH', 'POP_NHPI', 'POP_AIANNH', 'POP_AIAN', 'IND_AFFHM_MQE', 'HU_UIS02', 'HU_OCC_OPRgt200', 'IND_PSMAW_M', 'OCC_MBSA_ELCAM_L', 'OCC_SERV_PS_LE', 'HU_OCC_OPR151200', 'OCC_NRCM_FFF_x11', 'IND_AFFHM_AFFH', 'IND_TWU_U', 'IND_AFFHM', 'HU_OCC_OPR101150', 'OCC_MBSA_CES_LPSS', 'HH_7pP', 'OCC_MBSA_ELCAM_ADESM', 'POP_ASIANNH', 'POP_ASIAN', 'EDU_DOCT', 'HU_UIS2049', 'IND_INF_x7', 'HU_UIS50P', 'POP_A21', 'POP_A20', 'HU_UIS01A', 'EDU_PROF', 'POP_A8084', 'POP_A85p', 'HU_UIS1019', 'HU_UIS0304', 'POP_A6566', 'OCC_MBSA_CES_AE', 'OCC_MBSA_CES_CM', 'OCC_SERV_PS_FP', 'IND_FIRR_RR', 'POP_A1819', 'OCC_SERV_PS', 'OCC_SERV_HCS_x11', 'HH_6P', 'HU_UIS0509', 'OCC_SERV_BGM_x11', 'POP_A6061', 'OCC_MBSA_ELCAM_CSS', 'OCC_MBSA_HCPT_HTT', 'POP_A6769', 'IND_AERAF_AER', 'POP_OTH2PLNH', 'IND_WHT_x7', 'POP_HISP_x12', 'HHI_35_40k', 'OCC_SERV_PCS_x11', 'OCC_PTMM_MM_x11', 'POP_A7579', 'POP_A6264', 'HHI_30_35k', 'HHI_45_50k', 'IND_TWU_TW', 'OCC_MBSA_HCPT_HDTP', 'IND_PSMAW_ASWM', 'POP_A2224', 'POP_OTH2PL', 'OCC_NRCM_IMR_x11', 'IND_FIRR_FI', 'OCC_MBSA_CES', 'POP_A7074', 'IND_TWU', 'HHI_200k_p', 'IND_OSER_x7', 'POP_A1517', 'HHI_25_30k', 'HHI_10_15k', 'HHI_15_20k', 'OCC_NRCM_CE_x11', 'OCC_SERV_FPS_x11', 'OCC_PTMM_T_x11', 'HHI_00_10k', 'IND_PSMAW_PST', 'HHI_40_45k', 'POP_A0004', 'OCC_MBSA_MBF_BF', 'HHI_125_150k', 'HHI_150_200k', 'POP_A4044', 'HHI_20_25k', 'IND_FIRR', 'POP_A2529', 'POP_A0509', 'POP_A3034', 'OCC_MBSA_HCPT', 'POP_A5054', 'POP_A1014', 'IND_AERAF_AF', 'OCC_PTMM_P_x11', 'POP_A4549', 'HH_5P', 'POP_A5559', 'IND_CONS_x7', 'POP_A3539', 'OCC_MBSA_ELCAM_EL', 'HHI_50_60k', 'IND_EHCSA_E', 'EDU_ASSOC', 'IND_PUBA_x7', 'EDU_MAST', 'OCC_NRCM', 'HU_VAC', 'IND_PSMAW', 'IND_AERAF', 'OCC_MBSA_MBF_M', 'HHI_100_125k', 'HHI_60_75k', 'EDU_ltHS', 'OCC_SALES_OAS_x11', 'OCC_SALES_SR_x11', 'OCC_MBSA_ELCAM', 'IND_RETT_x7', 'IND_MAN_x7', 'IND_EHCSA_HCSA', 'HH_4P', 'HHI_75_100k', 'OCC_SERV', 'OCC_PTMM', 'OCC_MBSA_MBF', 'EDU_BACH', 'HH_3P', 'HU_UISOTHER', 'POP_BLACKNH', 'POP_BLACK', 'IND_EHCSA', 'OCC_SALES', 'HU_OCC_OPR051100', 'HU_OCC_RENT', 'HH_1P', 'HH_2P', 'OCC_MBSA', 'POP_M', 'POP_F', 'EDU_HS', 'HU_OCC_OPRlt050', 'HU_OCC_OWN', 'POP_WHITENH', 'HU_UIS01D', 'POP_WHITE', 'HINS_A1934', 'HINS_A3564', 'HU_OCC', 'POP_NH', 'HINS_A0018', 'HINS_A65p', 'HH_x5', 'POP_A3564', 'HU_x14', 'POP_16p_EMP_x7', 'POP_A25p', 'POP_x2', 'State', 'Cumtm1', 'Naive', 'State_pop', 'Ratio', 'Pop']

columns]

# %%
from sklearn.ensemble import RandomForestRegressor
# train time for random split at 0.1 test_size? 2 min
clf = RandomForestRegressor(random_state=666, max_depth=6)
clf.fit(X_train, y_train)


# from sklearn import linear_model
# clf = linear_model.Lasso(alpha=0.1)
# clf.fit(X_train, y_train)
# print(clf.coef_)
# print(clf.intercept_)

import numpy as np
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)
reg.coef_
# reg.intercept_
# Out:
# array([-2220184.872860, 2313.639391, -2220324.139269, 2436.100616,
#        -1997.129804, 131.056916, 1085.427693, 1169.798450, -641.564670,
#        849.813004, 1092.349478, 456.151604, -2000.855775, 3181.899633,
#        2470.420413, 1087.542016, -8237.981470, 0.431254, -645.117930,
#        -2220323.134401, 2430.432709, -7.385916, 126.210900, 477.775833,
#        134.925547, -5.807311, -8.655677, 131.896333, -1.406287, 11.274092,
#        19.391415, 131.102972, 131.016699, -0.596703, -8234.554585,
#        -8228.455287, 845.233627, 156.340025, 5.296418, -761.713386,
#        81.197594, 2.420192, 129.008406, 81.982021, 1.426316, -637.914859,
#        -714.840613, -1.472565, 156.406751, -2220325.642775, 479.477843,
#        -1110163.060220, -1.345083, 73.467196, -91.333147, 13.110590,
#        -3.638673, 1.529876, 1.495000, 3178.600174, -707.723123,
#        1162.934453, -6.465379, 2436.095927, 454.006765, 160.300030,
#        6102.968881, -0.915031, -2702.580038, 2.925455, 476.521576,
#        1.786058, -3.169768, 3.396685, -3.248332, 458.093944, 81.446058,
#        -89.017889, 1.059451, 1166.627908, 0.150170, 2.996112, -714.791555,
#        -1.601146, -5.111546, -2.939516, 2.037529, 316.635700, -5.325917,
#        2.704775, -1.729030, -1422.562192, 3.792071, -4.041135, 161.031814,
#        -91.453817, -7.097748, -0.880643, -5.452276, 466.046946, -7.642532,
#        -642.433597, -0.738755, 159.367407, 3.545012, 474.778608,
#        -2.269315, -812.178082, 436.099630, -689.603680, 317.439238,
#        -706.494876, 2.988270, 0.375441, 5.681856, -120.464384,
#        -122.959588, -1488.095204, 478.192880, 476.549432, 158.807898,
#        0.733184, -0.737362, -443.625664, -271.802958, -1421.280079,
#        -1.964029, -0.030423, 130.639602, -2220342.207764, 2452.922013,
#        318.175785, -243.427282, 1088.761363, -216.182551, -0.386396,
#        -2.287751, 1771.023390, 0.041845, -0.040938, 3.794415, 1092.749752,
#        -219.920262, -2220326.942050, 132.081075, 2438.511341, -1.028591,
#        -2.830971, -436.101361, 1110163.069127, 0.373956, 9.141965,
#        0.000004, -0.000003, -0.000010, 0.000006, 0.000004,
#        -1846900.001595, -11.497076, 0.000438, 12.695068, 0.000000,
#        1.928694, 1846900.001593])

# %%
coef = abs(reg.coef_)
# print(coef, abs(coef))
print(coef)

print(sorted(coef, reverse=True))
ind = np.argpartition(coef, -10)[-10:]
top = coef[ind]

print(ind,top)
# Out:
# [2220184.872860 2313.639391 2220324.139269 2436.100616 1997.129804
#  131.056916 1085.427693 1169.798450 641.564670 849.813004 1092.349478
#  456.151604 2000.855775 3181.899633 2470.420413 1087.542016 8237.981470
#  0.431254 645.117930 2220323.134401 2430.432709 7.385916 126.210900
# ...              ...          ...         ...         ...
# 304412      0.066028     0.007546    0.012770    0.010158
# 304413      0.066028     0.007546    0.012770    0.010158
# 304414      0.066028     0.007546    0.012770    0.010158
# 304415      0.066028     0.007546    0.012770    0.010158
# 304416      0.066028     0.007546    0.012770    0.010158
#
# [292085 rows x 10 columns]

# %%
from epsampling.utils import get_performance

y_pred = reg.predict(X_test)

model_names = ['Deaths_pred', 'Deaths_naive']
model_preds = [y_pred, y_naive]

metrics_dict = get_performance(model_names, model_preds, y_test, y_naive)
metrics_dict
# Out:
# {'Deaths_pred': {'MAE': 4.856512536818027,
#   'MSE': 161.32593542975604,
#   'RMSE': 12.701414701904511,
#   'r2': 0.017524461668948055,
#   'relMAE': 1.9819496067879394},
#  'Deaths_naive': {'MAE': 4.650093902653675,
#   'MSE': 166.89361440598498,
#   'RMSE': 12.91873114535576,
#   'r2': -0.01638272371233107,
#   'relMAE': 1.0}}

# %% [raw]
# 10:06
# 13 mins

# %% [raw]
# linear regression
#
# {'Deaths_pred': {'MAE': 4.856512536818027,
#   'MSE': 161.32593542975604,
#   'RMSE': 12.701414701904511,
#   'r2': 0.017524461668948055,
#   'relMAE': 1.9819496067879394},
#  'Deaths_naive': {'MAE': 4.650093902653675,
#   'MSE': 166.89361440598498,
#   'RMSE': 12.91873114535576,
#   'r2': -0.01638272371233107,
#   'relMAE': 1.0}}
#
# lasso a=0.1
#
# {'Deaths_pred': {'MAE': 4.917781434974449,
#   'MSE': 162.6398581859062,
#   'RMSE': 12.753033293530846,
#   'r2': 0.009522667265988383,
#   'relMAE': 2.358192357577101},
#  'Deaths_naive': {'MAE': 4.650093902653675,
#   'MSE': 166.89361440598498,
#   'RMSE': 12.91873114535576,
#   'r2': -0.01638272371233107,
#   'relMAE': 1.0}}
#
# lasso a=1.0
#
# {'Deaths_pred': {'MAE': 4.951333241297844,
#   'MSE': 162.63658713571513,
#   'RMSE': 12.752905046918334,
#   'r2': 0.009542587973646488,
#   'relMAE': 2.491038380998229},
#  'Deaths_naive': {'MAE': 4.650093902653675,
#   'MSE': 166.89361440598498,
#   'RMSE': 12.91873114535576,
#   'r2': -0.01638272371233107,
#   'relMAE': 1.0}}
#
# min-max normalization of everything
#
# {'Deaths_pred': {'MAE': 0.003998976739713239,
#   'MSE': 0.00011158522010094766,
#   'RMSE': 0.010563390558951594,
#   'r2': 0.013565975344652093,
#   'relMAE': 0.08290224995834859},
#
#  'Deaths_naive': {'MAE': 0.1295292657911756,
#   'MSE': 0.02106260566845557,
#   'RMSE': 0.14512961678601502,
#   'r2': -185.19733742933863,
#   'relMAE': 1.0}}
#
#
# change target to x / X * 100000
#
# {'Deaths_pred': {'MAE': 4.818035544257456,
#   'MSE': 161.97554298395673,
#   'RMSE': 12.726961262766409,
#   'r2': 0.013568349281828929,
#   'relMAE': 2.0277204372763693},
#
#  'Deaths_naive': {'MAE': 4.650093902653675,
#   'MSE': 166.89361440598498,
#   'RMSE': 12.91873114535576,
#   'r2': -0.01638272371233107,
#   'relMAE': 1.0}}
